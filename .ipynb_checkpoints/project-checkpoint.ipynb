# %% [markdown]
# # Initialize MongoDB client
# See README.md for setup instructions.

# %%
import os
from urllib.parse import quote_plus
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

username = quote_plus('common')
password = quote_plus(os.environ.get('MONGODB_PASSWORD'))
uri = f"mongodb+srv://{username}:{password}@playervaluations.v7jevdf.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import json

db = client['player_valuations']
collection = db['players']
player = collection.find_one({'player_id': 65})

# Print the result
if player:
    print("Player found:", json.dumps(player, indent=4, default=str))
else:
    print("No player found with player_id", 65)
# Out:
# Player found: {
#     "_id": "65a01328c758554bfe6e0d31",
#     "player_id": 65,
#     "first_name": "Dimitar",
#     "last_name": "Berbatov",
#     "name": "Dimitar Berbatov",
#     "last_season": 2015,
#     "current_club_id": 1091,
#     "player_code": "dimitar-berbatov",
#     "country_of_birth": "Bulgaria",
#     "city_of_birth": "Blagoevgrad",
#     "country_of_citizenship": "Bulgaria",
#     "date_of_birth": "1981-01-30",
#     "sub_position": "Centre-Forward",
#     "position": "Attack",
#     "foot": NaN,
#     "height_in_cm": NaN,
#     "contract_expiration_date": NaN,
#     "agent_name": "CSKA-AS-23 Ltd.",
#     "image_url": "https://img.a.transfermarkt.technology/portrait/header/65-1683670068.jpg?lm=1",
#     "url": "https://www.transfermarkt.co.uk/dimitar-berbatov/profil/spieler/65",
#     "current_club_domestic_competition_id": "GR1",
#     "current_club_name": "Panthessalonikios Athlitikos Omilos Konstantinoupoliton",
#     "market_value_in_eur": 1000000.0,
#     "highest_market_value_in_eur": 34500000.0,
#     "valuations": [
#         {
#             "player_id": 65,
#             "date": "2004-10-04",
#             "datetime": "2004-10-04 00:00:00",
#             "dateweek": "2004-10-04",
#             "market_value_in_eur": 8000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2005-06-22",
#             "datetime": "2005-06-22 00:00:00",
#             "dateweek": "2005-06-20",
#             "market_value_in_eur": 12000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2005-09-30",
#             "datetime": "2005-09-30 00:00:00",
#             "dateweek": "2005-09-26",
#             "market_value_in_eur": 14500000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2006-01-09",
#             "datetime": "2006-01-09 00:00:00",
#             "dateweek": "2006-01-09",
#             "market_value_in_eur": 13500000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2006-04-07",
#             "datetime": "2006-04-07 00:00:00",
#             "dateweek": "2006-04-03",
#             "market_value_in_eur": 15000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2006-06-02",
#             "datetime": "2006-06-02 00:00:00",
#             "dateweek": "2006-05-29",
#             "market_value_in_eur": 17000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2007-04-27",
#             "datetime": "2007-04-27 00:00:00",
#             "dateweek": "2007-04-23",
#             "market_value_in_eur": 17600000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2007-08-02",
#             "datetime": "2007-08-02 00:00:00",
#             "dateweek": "2007-07-30",
#             "market_value_in_eur": 27000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2008-02-04",
#             "datetime": "2008-02-04 00:00:00",
#             "dateweek": "2008-02-04",
#             "market_value_in_eur": 24000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2008-07-04",
#             "datetime": "2008-07-04 00:00:00",
#             "dateweek": "2008-06-30",
#             "market_value_in_eur": 26000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2008-09-07",
#             "datetime": "2008-09-07 00:00:00",
#             "dateweek": "2008-09-01",
#             "market_value_in_eur": 32000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2009-02-23",
#             "datetime": "2009-02-23 00:00:00",
#             "dateweek": "2009-02-23",
#             "market_value_in_eur": 34500000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2009-06-29",
#             "datetime": "2009-06-29 00:00:00",
#             "dateweek": "2009-06-29",
#             "market_value_in_eur": 33000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2010-01-25",
#             "datetime": "2010-01-25 00:00:00",
#             "dateweek": "2010-01-25",
#             "market_value_in_eur": 29000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2010-08-13",
#             "datetime": "2010-08-13 00:00:00",
#             "dateweek": "2010-08-09",
#             "market_value_in_eur": 25000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2011-02-01",
#             "datetime": "2011-02-01 00:00:00",
#             "dateweek": "2011-01-31",
#             "market_value_in_eur": 28000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2011-08-08",
#             "datetime": "2011-08-08 00:00:00",
#             "dateweek": "2011-08-08",
#             "market_value_in_eur": 24000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2012-02-06",
#             "datetime": "2012-02-06 00:00:00",
#             "dateweek": "2012-02-06",
#             "market_value_in_eur": 17000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2012-06-24",
#             "datetime": "2012-06-24 00:00:00",
#             "dateweek": "2012-06-18",
#             "market_value_in_eur": 11500000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2012-09-09",
#             "datetime": "2012-09-09 00:00:00",
#             "dateweek": "2012-09-03",
#             "market_value_in_eur": 10000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2013-01-28",
#             "datetime": "2013-01-28 00:00:00",
#             "dateweek": "2013-01-28",
#             "market_value_in_eur": 7000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2013-07-02",
#             "datetime": "2013-07-02 00:00:00",
#             "dateweek": "2013-07-01",
#             "market_value_in_eur": 5000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2014-01-15",
#             "datetime": "2014-01-15 00:00:00",
#             "dateweek": "2014-01-13",
#             "market_value_in_eur": 3500000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2014-08-07",
#             "datetime": "2014-08-07 00:00:00",
#             "dateweek": "2014-08-04",
#             "market_value_in_eur": 3000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2015-01-14",
#             "datetime": "2015-01-14 00:00:00",
#             "dateweek": "2015-01-12",
#             "market_value_in_eur": 2500000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2015-06-06",
#             "datetime": "2015-06-06 00:00:00",
#             "dateweek": "2015-06-01",
#             "market_value_in_eur": 1000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2015-09-27",
#             "datetime": "2015-09-27 00:00:00",
#             "dateweek": "2015-09-21",
#             "market_value_in_eur": 1000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         },
#         {
#             "player_id": 65,
#             "date": "2016-06-21",
#             "datetime": "2016-06-21 00:00:00",
#             "dateweek": "2016-06-20",
#             "market_value_in_eur": 1000000,
#             "current_club_id": 1091,
#             "player_club_domestic_competition_id": "GR1"
#         }
#     ]
# }

# %% [markdown]
# # Close MongoDB client

# %%
client.close()
